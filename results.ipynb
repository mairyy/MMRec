# %%
# !python main.py --data Beauty --seed 634524364
# Out:
# Namespace(lr=0.001, seed=634524364, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem')
# 2023-12-31 14:52:52.075694: Start
# 2023-12-31 14:52:58.743575: Load Data
# 2023-12-31 14:52:58.743627: Users: 22363, Items(+1): 12102
# 2023-12-31 14:52:58.781033: Model Prepared
# 2023-12-31 14:52:58.781071: Model Initialized
# Test result: h5=0.0439 n5=0.0261 h10=0.0910 n10=0.0410 h20=0.1911 n20=0.0660 h50=0.4981 n50=0.1260 hr@20 = 15.00, ndcg@20 = 4.66, hr@50 = 40.00, ndcg@50 = 9.54 .96
# 2023-12-31 14:55:45.332110: Epoch 0/20, Train: loss = -49.2740, loss_main = 1.3106, loss_reco = -50.5295, loss_mask = -0.6090
# ...

# %%
# !python main.py --data Beauty --seed 1235436473
# Out:
# Namespace(lr=0.001, seed=1235436473, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem')
# 2023-12-31 15:42:13.001525: Start
# 2023-12-31 15:42:16.699017: Load Data
# 2023-12-31 15:42:16.699070: Users: 22363, Items(+1): 12102
# 2023-12-31 15:42:16.708320: Model Prepared
# 2023-12-31 15:42:16.708359: Model Initialized
# Test result: h5=0.0484 n5=0.0293 h10=0.0956 n10=0.0444 h20=0.1918 n20=0.0684 h50=0.4972 n50=0.1279 hr@20 = 16.00, ndcg@20 = 5.11, hr@50 = 45.00, ndcg@50 = 10.85 5.50
# 2023-12-31 15:44:46.393475: Epoch 0/20, Train: loss = -49.2737, loss_main = 1.2988, loss_reco = -50.5332, loss_mask = -0.4359
# ...

# %%
# !python main.py --data Beauty --seed 867441313
# Out:
# Namespace(lr=0.001, seed=867441313, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem')
# 2023-12-31 16:30:49.128314: Start
# 2023-12-31 16:30:52.921017: Load Data
# 2023-12-31 16:30:52.921069: Users: 22363, Items(+1): 12102
# 2023-12-31 16:30:52.930103: Model Prepared
# 2023-12-31 16:30:52.930139: Model Initialized
# Test result: h5=0.0492 n5=0.0301 h10=0.0969 n10=0.0453 h20=0.1943 n20=0.0696 h50=0.4906 n50=0.1273, hr@20 = 13.00, ndcg@20 = 5.12, hr@50 = 34.00, ndcg@50 = 9.12 71 1
# 2023-12-31 16:33:29.671545: Epoch 0/20, Train: loss = -49.2661, loss_main = 1.2998, loss_reco = -50.5344, loss_mask = -0.3525
# ...

# %%
# !python main.py --data Beauty --seed 235143593
# Out:
# Namespace(lr=0.001, seed=235143593, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem')
# 2023-12-31 14:48:19.727824: Start
# 2023-12-31 14:48:24.932551: Load Data
# 2023-12-31 14:48:24.932621: Users: 22363, Items(+1): 12102
# 2023-12-31 14:48:24.956684: Model Prepared
# 2023-12-31 14:48:24.956723: Model Initialized
# Test result: h5=0.0493 n5=0.0287 h10=0.0990 n10=0.0445 h20=0.1960 n20=0.0687 h50=0.4940 n50=0.1268 hr@20 = 12.00, ndcg@20 = 4.37, hr@50 = 42.00, ndcg@50 = 10.40 .01
# 2023-12-31 14:51:01.150262: Epoch 0/20, Train: loss = -49.2677, loss_main = 1.2938, loss_reco = -50.5328, loss_mask = -0.3203
# ...

# %%
# !python main.py --data Beauty --seed 1254435436
# Out:
# Namespace(lr=0.001, seed=1254435436, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem')
# 2023-12-31 16:17:03.938305: Start
# 2023-12-31 16:17:07.884143: Load Data
# 2023-12-31 16:17:07.884203: Users: 22363, Items(+1): 12102
# 2023-12-31 16:17:07.893700: Model Prepared
# 2023-12-31 16:17:07.893741: Model Initialized
# Test result: h5=0.0500 n5=0.0301 h10=0.1010 n10=0.0463 h20=0.1989 n20=0.0708 h50=0.5025 n50=0.1299, hr@20 = 21.00, ndcg@20 = 8.64, hr@50 = 49.00, ndcg@50 = 14.16 .30
# 2023-12-31 16:19:47.216354: Epoch 0/20, Train: loss = -49.2667, loss_main = 1.2959, loss_reco = -50.5337, loss_mask = -0.3243
# ...
