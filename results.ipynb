# %%
# !python main.py --data Beauty --mode graph_t
# Out:
# Namespace(lr=0.001, seed=19260817, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem', mode='graph_t', f_dim=1024, f_new_dim=64, knn=5, img_weight=0.5)
# 2024-01-03 01:27:47.358483: Start
# 2024-01-03 01:27:52.878371: Load Data
# 2024-01-03 01:27:52.878427: Users: 22363, Items(+1): 12102
# 2024-01-03 01:27:55.467979: Model Prepared
# 2024-01-03 01:27:55.468026: Model Initialized
# Test result: h5=0.0008 n5=0.0005 h10=0.0009 n10=0.0005 h20=0.0017 n20=0.0007 h50=0.0045 n50=0.0012 hr@20 = 0.00, ndcg@20 = 0.00, hr@50 = 0.00, ndcg@50 = 0.00
# ...

# %%
# !python main.py --data Beauty --mode graph_v
# Out:
# Namespace(lr=0.001, seed=19260817, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem', mode='graph_v', f_dim=1024, f_new_dim=64, knn=5, img_weight=0.5)
# 2024-01-03 04:10:23.063293: Start
# 2024-01-03 04:10:27.029935: Load Data
# 2024-01-03 04:10:27.030013: Users: 22363, Items(+1): 12102
# 2024-01-03 04:10:27.903743: Model Prepared
# 2024-01-03 04:10:27.903789: Model Initialized
# Test result: h5=0.0008 n5=0.0005 h10=0.0010 n10=0.0005 h20=0.0016 n20=0.0007 h50=0.0045 n50=0.0012 hr@20 = 0.00, ndcg@20 = 0.00, hr@50 = 0.00, ndcg@50 = 0.00
# ...

# %%
# !python main.py --data Beauty --mode graph_mm
# Out:
# Namespace(lr=0.001, seed=19260817, data='Beauty', epoch=20, trn_batch=256, tst_batch=256, con_batch=2048, test_frequency=1, max_seq_len=50, num_reco_neg=40, reg=1e-06, ssl_reg=0.01, latdim=32, mask_depth=3, path_prob=0.5, num_attention_heads=4, num_gcn_layers=2, num_trm_layers=2, load_model=None, num_mask_cand=50, mask_steps=10, eps=0.2, attention_probs_dropout_prob=0.3, hidden_dropout_prob=0.3, save_path='tem', mode='graph_mm', f_dim=1024, f_new_dim=64, knn=5, img_weight=0.5)
# 2024-01-03 06:52:52.357839: Start
# 2024-01-03 06:52:56.265580: Load Data
# 2024-01-03 06:52:56.265637: Users: 22363, Items(+1): 12102
# 2024-01-03 06:52:57.242654: Model Prepared
# 2024-01-03 06:52:57.242699: Model Initialized
# Test result: h5=0.0007 n5=0.0004 h10=0.0010 n10=0.0005 h20=0.0016 n20=0.0007 h50=0.0044 n50=0.0012 hr@20 = 0.00, ndcg@20 = 0.00, hr@50 = 0.00, ndcg@50 = 0.00
# ...
